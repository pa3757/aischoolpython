# %% [markdown]
# ### model fine-tuning
# - 사전에 학습된모델에 나의 목적에 맞는 데이터를 추가 학습시켜서 수정하는 기법

# %% [markdown]
# <br/>
#
# ### 학습목표
# - Vision Transformer 모델을 파인튜닝 해보자
# <br/>
#
# ### Vision Transformer(ViT)
# - 구글 브레인의 연구팀이 2021년 발표
# - 처리방법
#   1. 원본 이미지를 격자형태로 쪼개 서브 이미지로 만든다.
#   2. 쪼개진 이미지를 선형으로 투영한다.
#   3. 투영된 데이터를 자연어처리하는 것처럼 ViT모델 입력으로 사용한다.
#   ![image.png](data:image/png;base64,...)

# %%
#  관련 라이브러리 설치
# !pip install transformers datasets

# %%
# 버전이 낮은 라이브러리 업데이트
# !p  ip install accelerate -U
