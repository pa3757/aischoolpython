# %%
import pandas as pd
requests = __import__('requests')

url = 'https://pokeapi.co/api/v2/pokemon/'
koreannameurl = 'https://pokeapi.co/api/v2/pokemon-species'

res = requests.get(url)
res2 = requests.get(koreannameurl+ '/1')

pokemon = res.json()
pokemon2 = res2.json()
# Out:
# {'baby_trigger_item': None,
#  'chain': {'evolution_details': [],
#   'evolves_to': [{'evolution_details': [{'gender': None,
#       'held_item': None,
#       'item': None,
#       'known_move': None,
#       'known_move_type': None,
#       'location': None,
#       'min_affection': None,
#       'min_beauty': None,
#       'min_happiness': None,
#       'min_level': 16,
#       'needs_overworld_rain': False,
#       'party_species': None,
#       'party_type': None,
#       'relative_physical_stats': None,
#       'time_of_day': '',
#       'trade_species': None,
#       'trigger': {'name': 'level-up',
#        'url': 'https://pokeapi.co/api/v2/evolution-trigger/1/'},
#       'turn_upside_down': False}],
#     'evolves_to': [{'evolution_details': [{'gender': None,
#         'held_item': None,
#         'item': None,
#         'known_move': None,
#         'known_move_type': None,
#         'location': None,
#         'min_affection': None,
#         'min_beauty': None,
#         'min_happiness': None,
#         'min_level': 32,
#         'needs_overworld_rain': False,
#         'party_species': None,
#         'party_type': None,
#         'relative_physical_stats': None,
#         'time_of_day': '',
#         'trade_species': None,
#         'trigger': {'name': 'level-up',
#          'url': 'https://pokeapi.co/api/v2/evolution-trigger/1/'},
#         'turn_upside_down': False}],
#       'evolves_to': [],
#       'is_baby': False,
#       'species': {'name': 'venusaur',
#        'url': 'https://pokeapi.co/api/v2/pokemon-species/3/'}}],
#     'is_baby': False,
#     'species': {'name': 'ivysaur',
#      'url': 'https://pokeapi.co/api/v2/pokemon-species/2/'}}],
#   'is_baby': False,
#   'species': {'name': 'bulbasaur',
#    'url': 'https://pokeapi.co/api/v2/pokemon-species/1/'}},
#  'id': 1}

# %%
pokemon_list = []
for i in range(1, 151):
    res = requests.get(url + str(i))
    pokemon = res.json()
    res2 = requests.get(koreannameurl + '/' + str(i))
    pokemon2 = res2.json()
    pokemon_list.append({
        'id' : pokemon['id'],
        'name': pokemon['name'],
        'koreanname': pokemon2['names'][2]['name'],
        'height': pokemon['height'],
        'weight': pokemon['weight'],
        'types': [t['type']['name'] for t in pokemon['types']],
        'img-url': pokemon['sprites']['front_default'],
        'gif-url' : pokemon['sprites']['other']['showdown']['front_default']
    })

# %%
# dataframe으로 변환
df = pd.DataFrame(pokemon_list)
df
# Out:
#       id        name  height  weight             types koreanname  \
# 0      1   bulbasaur       7      69   [grass, poison]       이상해씨
# 1      2     ivysaur      10     130   [grass, poison]       이상해풀
# 2      3    venusaur      20    1000   [grass, poison]       이상해꽃
# 3      4  charmander       6      85            [fire]        파이리
# 4      5  charmeleon      11     190            [fire]        리자드
# ..   ...         ...     ...     ...               ...        ...
# 145  146     moltres      20     600    [fire, flying]        파이어
# 146  147     dratini      18      33          [dragon]         미뇽
# 147  148   dragonair      40     165          [dragon]         신뇽
# 148  149   dragonite      22    2100  [dragon, flying]        망나뇽
# 149  150      mewtwo      20    1220         [psychic]         뮤츠
#
#                                                  image  \
# 0    https://raw.githubusercontent.com/PokeAPI/spri...
# 1    https://raw.githubusercontent.com/PokeAPI/spri...
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3    https://raw.githubusercontent.com/PokeAPI/spri...
# 4    https://raw.githubusercontent.com/PokeAPI/spri...
# ..                                                 ...
# 145  https://raw.githubusercontent.com/PokeAPI/spri...
# 146  https://raw.githubusercontent.com/PokeAPI/spri...
# 147  https://raw.githubusercontent.com/PokeAPI/spri...
# 148  https://raw.githubusercontent.com/PokeAPI/spri...
# 149  https://raw.githubusercontent.com/PokeAPI/spri...
#
#                                                 image2
# 0    https://raw.githubusercontent.com/PokeAPI/spri...
# 1    https://raw.githubusercontent.com/PokeAPI/spri...
# 2    https://raw.githubusercontent.com/PokeAPI/spri...
# 3    https://raw.githubusercontent.com/PokeAPI/spri...
# 4    https://raw.githubusercontent.com/PokeAPI/spri...
# ..                                                 ...
# 145  https://raw.githubusercontent.com/PokeAPI/spri...
# 146  https://raw.githubusercontent.com/PokeAPI/spri...
# 147  https://raw.githubusercontent.com/PokeAPI/spri...
# 148  https://raw.githubusercontent.com/PokeAPI/spri...
# 149  https://raw.githubusercontent.com/PokeAPI/spri...
#
# [150 rows x 8 columns]
