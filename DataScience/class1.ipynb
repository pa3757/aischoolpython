# %%
import numpy as np
# 우리가 원하는 특정한 값으로 배열을 만들어보기
print(np.full((2, 3), 7))
# Out:
# [[7 7 7]
#  [7 7 7]]

# %%
import pandas as pd
data = pd.read_csv('./data/Traffic_Accident_2017.csv', encoding='euc-kr')
data
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 0     2017  2017010101   15  야간  일     1     2     1     0       0  ...
# 1     2017  2017010102   28  야간  일     1     1     0     0       0  ...
# 2     2017  2017010102   43  야간  일     1     2     0     1       0  ...
# 3     2017  2017010102   22  야간  일     1     1     0     0       0  ...
# 4     2017  2017010104   37  야간  일     1     1     0     0       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4060  2017  2017123118   10  야간  일     1     4     1     0       2  ...
# 4061  2017  2017123118   25  야간  일     1     1     0     0       0  ...
# 4062  2017  2017123119   55  야간  일     1     1     0     0       0  ...
# 4063  2017  2017123120   40  야간  일     1    11     1     9       0  ...
# 4064  2017  2017123123   15  야간  일     1     1     0     0       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류  당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
# 차대사람 사건 중 야간에 발생한 사건에 대한 데이터만 추출
data2 =data[data['사고유형_대분류'] == '차대사람']
data2
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 1     2017  2017010102   28  야간  일     1     1     0     0       0  ...
# 4     2017  2017010104   37  야간  일     1     1     0     0       0  ...
# 5     2017  2017010104    0  야간  일     1     2     1     0       0  ...
# 6     2017  2017010105   50  야간  일     1     1     0     0       0  ...
# 11    2017  2017010203   30  야간  월     1     2     0     1       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4053  2017  2017123018   36  야간  토     1     1     0     0       0  ...
# 4056  2017  2017123100   50  야간  일     1     1     0     0       0  ...
# 4057  2017  2017123107    4  주간  일     1     1     0     0       0  ...
# 4059  2017  2017123117   56  주간  일     1     1     0     0       0  ...
# 4064  2017  2017123123   15  야간  일     1     1     0     0       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
data3 = data2[data2['주야']=='야간']
data3
# Out:
#        발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ...  \
# 1     2017  2017010102   28  야간  일     1     1     0     0       0  ...
# 4     2017  2017010104   37  야간  일     1     1     0     0       0  ...
# 5     2017  2017010104    0  야간  일     1     2     1     0       0  ...
# 6     2017  2017010105   50  야간  일     1     1     0     0       0  ...
# 11    2017  2017010203   30  야간  월     1     2     0     1       0  ...
# ...    ...         ...  ...  .. ..   ...   ...   ...   ...     ...  ...
# 4046  2017  2017123003   42  야간  토     1     1     0     0       0  ...
# 4052  2017  2017123018   50  야간  토     2     2     0     0       0  ...
# 4053  2017  2017123018   36  야간  토     1     1     0     0       0  ...
# 4056  2017  2017123100   50  야간  일     1     1     0     0       0  ...
# 4064  2017  2017123123   15  야간  일     1     1     0     0       0  ...
#
#      도로형태_대분류   도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK  \
# ...

# %%
data4 =data3['요일'].value_counts()
data4
# Out:
# 요일
# 토    162
# 화    145
# 수    142
# 금    137
# 목    134
# 월    123
# 일    121
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm


font_path = 'C:/Windows/Fonts/malgun.ttf'  
font_prop = fm.FontProperties(fname=font_path)
plt.rc('font', family=font_prop.get_name())

# bar 차트 그리기 (월~일, x축 글자 회전)
data4.plot(kind='bar', rot=0)

plt.xlabel('요일')
plt.ylabel('사고건수')
plt.title('요일별 야간 차대사람 교통사고 건수')
plt.show()

# %%
import pandas as pd
data = pd.read_csv('./data/HR데이터/data/hr-info.csv', encoding='euc-kr')
data
# Out:
#         EID ENAME GENDER  ORG_CD POS_CD  AGE  SERVICE_YEAR EDU_LEVEL  \
# 0    E00206   시이오      M     NaN   P001   49            25     박사 학위
# 1    E00181   나사장      F     NaN   P002   49            24     박사 학위
# 2    E00164  난부사장      M     NaN   P003   48            22     박사 학위
# 3    E00190   판라다      F  ORG007   P004   47            18     박사 학위
# 4    E00209   누훈봉      M  ORG023   P004   47            19     박사 학위
# ..      ...   ...    ...     ...    ...  ...           ...       ...
# 195  E00322   부탐회      F  ORG014   P009   23             0     학사 학위
# 196  E00389   초두반      F  ORG012   P009   23             0     학사 학위
# 197  E00438   권개득      M  ORG024   P009   23             0     학사 학위
# 198  E00304   탐출조      M  ORG009   P009   24             0     학사 학위
# 199  E00428   을충나      F  ORG003   P009   24             0     학사 학위
#
#      PERFORMANCE_SCORE  SALARY LAST_PROMO_DT  TRAINING_HOURS  \
# 0                 4.50   10200    2024-03-01             240
# ...

# %%
data2 = pd.read_csv('./data/HR데이터/data/org-info.csv', encoding='euc-kr')
data2
# Out:
#     ORG_CD                               ENG_DIVISION KOR_DIVISION  \
# 0   ORG001                Home Entertainment Division       HE사업본부
# 1   ORG002                Home Entertainment Division       HE사업본부
# 2   ORG003                Home Entertainment Division       HE사업본부
# 3   ORG004                Home Entertainment Division       HE사업본부
# 4   ORG005                Home Entertainment Division       HE사업본부
# 5   ORG006                Home Entertainment Division       HE사업본부
# 6   ORG007                 Vehicle Solutions Division       VS사업본부
# 7   ORG008                 Vehicle Solutions Division       VS사업본부
# 8   ORG009                 Vehicle Solutions Division       VS사업본부
# 9   ORG010                 Vehicle Solutions Division       VS사업본부
# 10  ORG011                 Vehicle Solutions Division       VS사업본부
# 11  ORG012                 Vehicle Solutions Division       VS사업본부
# 12  ORG013   Home Appliance and Air Solution Division       HA사업본부
# ...

# %%
# 데이터 준비
org_agg = data.groupby(by='ORG_CD').agg({'ENAME':'count', 'AGE' : 'mean', 'SERVICE_YEAR' : 'mean', 'SALARY' : 'mean'})
org_agg
# Out:
#         ENAME        AGE  SERVICE_YEAR       SALARY
# ORG_CD
# ORG001      6  26.166667      0.333333  5033.333333
# ORG002      4  34.000000      7.500000  6550.000000
# ORG003      5  34.600000      7.600000  6480.000000
# ORG004     11  35.181818      7.000000  6445.454545
# ORG005      8  29.250000      2.000000  5525.000000
# ORG006      6  30.833333      4.166667  5966.666667
# ORG007      7  36.714286      8.000000  6728.571429
# ORG008      5  32.400000      5.200000  6020.000000
# ORG009      5  29.800000      2.200000  5520.000000
# ORG010      3  33.333333      5.666667  6300.000000
# ORG011      5  37.400000      8.400000  6660.000000
# ORG012      5  29.600000      2.600000  5680.000000
# ORG013      8  32.625000      3.625000  5950.000000
# ORG014      8  32.750000      5.000000  6025.000000
# ORG015      3  24.666667      0.000000  5000.000000
# ORG016      8  35.000000      7.250000  6500.000000
# ORG017     10  29.400000      2.700000  5520.000000
# ...

# %%
org_agg.index
# Out:
# Index(['ORG001', 'ORG002', 'ORG003', 'ORG004', 'ORG005', 'ORG006', 'ORG007',
#        'ORG008', 'ORG009', 'ORG010', 'ORG011', 'ORG012', 'ORG013', 'ORG014',
#        'ORG015', 'ORG016', 'ORG017', 'ORG018', 'ORG019', 'ORG020', 'ORG021',
#        'ORG022', 'ORG023', 'ORG024', 'ORG025', 'ORG026', 'ORG027', 'ORG028',
#        'ORG029', 'ORG030'],
#       dtype='object', name='ORG_CD')

# %%
import winfetch

winfetch.fetch()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 3
#       1 import winfetch
# ----> 3 winfetch.fetch()
#
# AttributeError: module 'winfetch' has no attribute 'fetch'
